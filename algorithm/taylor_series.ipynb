# %% [markdown]
# {微分}
#
# f'(x) = lim\[h->0\](f(x+h)-f(x))/h
# \f(x) = \lim_{{\h} \to 0}
# 中心差微分
# f'(x)≒ lim\[h->0\](f(x+h)-f(x-h))/2h

# %%
# %%latex
# \text{微分}\\
# f(x) =
# Out:
# \text{微分}\\
# f(x) =

# %%
class taylor:
    def __init__(self, approximate: int, point: int) -> None:
        self.n = approximate
        self.a = point
        pass
    def numerical_diff() -> int:

        return value
