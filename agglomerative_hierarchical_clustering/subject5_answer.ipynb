# %%
matrix = np.array([apartments[apartment] for apartment in apartments])
apartments_list = np.array(list(apartments.keys()))
linkage_arr = ward(matrix)
dendrogram(linkage_arr, labels=apartments_list)
