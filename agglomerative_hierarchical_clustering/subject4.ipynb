# %%
from scipy.cluster.hierarchy import dendrogram, ward, linkage
import numpy as np
import matplotlib.pyplot as plt

# %%
#apartmentsでデンドログラムを作成せよ
apartments = {'A':np.array([1, 3]),
             'B':np.array([2, 2]),
             'C':np.array([3, 4]),
             'D':np.array([7, 9]),
             'E':np.array([8, 7]),
             'F':np.array([9, 9])}
apartment_matrix = np.array([[1, 3],
                             [2, 2],
                             [3, 4],
                             [7, 9],
                             [8, 7],
                             [9, 9]])
#------------------code--------------------#

#------------------//code------------------#
