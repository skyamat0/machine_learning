# %%
# !pip install tensorflow

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import model
from tensorfow.keras.layers import Dense, Input, Flatten
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-0b3336efca45> in <module>()
#       1 from tensorflow.keras.datasets import mnist
# ----> 2 from tensorflow.keras.models import model
#       3 from tensorfow.keras.layers import Dense, Input, Flatten
#
# ImportError: cannot import name 'model' from 'tensorflow.keras.models' (/usr/local/lib/python3.7/dist-packages/tensorflow/keras/models/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
