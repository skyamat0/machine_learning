# %%
# ライブラリのインポート
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.datasets import fetch_california_housing

# データセットを用意
california = fetch_california_housing()
california_df = pd.DataFrame(data=california.data, columns=california.feature_names)
california_df["MEDV"] = california.target
california_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude   MEDV
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]

# %% [markdown]
# # 目的変数をMEDV，説明変数をその他にして重回帰モデルを作成せよ．
#
# * データの分割
# * データの標準化
#
# を行うこと．
#
# ## advance
#
# * 正則化線形回帰を実装せよ
# * 勾配降下法または，正規方程式を解くことによってパラメータを求め，回帰モデルを作成せよ
#
# ```python
# X_inverse = np.linalg.inv(X)
# ```

# %%
# Out:
# 訓練データ精度=0.6112583475310978
# テストデータ精度=0.5926096960745021
# 偏回帰係数=[[ 0.84877568  0.11560106 -0.29220264  0.30436255 -0.01059792 -0.04243209
#   -0.87367842 -0.84838395]]
# 定数項=[2.07121612]
# 目的変数の平均値2.0683413684501972
#                    0
# MedInc      0.848776
# HouseAge    0.115601
# AveRooms   -0.292203
# AveBedrms   0.304363
# Population -0.010598
# AveOccup   -0.042432
# Latitude   -0.873678
# Longitude  -0.848384
