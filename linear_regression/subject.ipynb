# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_linnerud

# %%
linnerud = load_linnerud()
#説明変数：懸垂の回数(chins),腹筋の回数(situps),跳躍(jumps) 
#目的変数 : 体重,ウエスト,脈拍(どれかを選択)
