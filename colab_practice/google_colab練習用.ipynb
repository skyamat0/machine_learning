# %%
#1-1
#print関数で1+1の計算結果を出力せよ

# %%
#1-2
#テキストでHello worldを書いてみよ

# %%
1-3
def文を使って、hello()と実行したら"hello world"と出力される関数helloを作成せよ

# %%
1-4
1~100までのfizzbuzzを出力せよ

# %%
1-5
super advance 再帰関数でfizzbuzzせよ（条件は上と同じ）

# %%
1-6
次のような配列が与えられる
'''
...#S
G..#.
......
'''
この時幅優先探索によって、ゴールまで到達できる最短のステップを出力せよ
