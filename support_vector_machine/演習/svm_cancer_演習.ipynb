# %% [markdown]
# # SVM分類器を作成する
#
# ## 注意！！！
# svmは基本的に標準化が必要．
#
# アルゴリズムで「サポートベクター間の距離」が使われるため，標準化が必要になっている．

# %%
from sklearn.svm import SVC
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
import numpy as np
a = np.array([10, 60000])
b = np.array([5, 80000])
np.linalg.norm(a-b)
# Out:
# 20000.00062499999

# %% [markdown]
# 上記の例だと，ほぼほぼgの情報しか入っていない．
# kmに関する情報はこの距離には反映されていない．

# %%
x = np.array([km, g]).T
sscaler = StandardScaler()
sscaler.fit(x)
x = sscaler.transform(x)
print(x)
np.linalg.norm(x)
# Out:
# [[ 1. -1.]
#  [-1.  1.]]
# 2.0

# %% [markdown]
# これで，kmの情報とgの情報が距離に均等に反映されるようになった．

# %%
cancer = load_breast_cancer()
X = cancer.data
y = cancer.target
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
# 訓練データを標準化しよう

# 標準化のためのインスタンスを生成
sscaler = # WRITE ME

# 訓練データから平均や標準偏差を学習
# WRITE ME

# 学習したsscalerを使って訓練データを変換
X_train_scaled = # WRITE ME

# 同様のsscalerでテストデータを変換
X_test_scaled = # WRITE ME

# %%
# 訓練データを使って学習

# svmのインスタンスを生成
args = {"C":1, "kernel":"rbf"}
svc =  # WRITE ME

# svmモデルを学習
# WRITE ME

# 精度を見る
print("訓練データ精度:", svc.score(X_train_scaled, y_train))
print("テストデータ精度:", svc.score(X_test_scaled, y_test))
# Out:
# 訓練データ精度: 0.9859154929577465
# テストデータ精度: 0.965034965034965
