# %%
#subject3
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import GridSearchCV, train_test_split, KFold
import matplotlib.pyplot as plt

# %%
#説明変数Xと目的変数yを定義し、訓練データとテストデータに分割

# %%
#モデルを学習
#精度を確認

# %%
#グリッドサーチによってkの数を最適化

# %%
#最適化された値で精度を確認

# %%
#graph化(n_neighborsとaccuracyの関係をグラフ化)
#X軸の値をn_neighborsにし、y軸の値をtrain_accuracyとtest_accuracyそれぞれにしたもので折れ線グラフを作成
#要は1つの図に2つのグラフ(n_neighbors vs train_accuracyとn_neighbors vs test_accuracy)を載せる
#n_neighbors -> 1~10
#train accuracy と test accuracyをグラフ化
